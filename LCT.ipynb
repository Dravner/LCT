# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
# %matplotlib inline
from sklearn import tree
from sklearn.metrics import roc_curve, auc
from graphviz  import Source
from IPython.display import SVG, display, HTML
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
style = "<style>svg{width: 50% !important; height: 50% !important;} </style>"

# %%
cabin = pd.read_csv('CABIN_2019.csv', sep = ';')

# %%
cabin
# Out:
#               DAT_S  SAK  FLT_NUM    DEP_DATE  LGNUM SEG_ORIG SEG_DEST  \
# 0        01.04.2019  SU      1116  31.03.2019      1     SVO      AER
# 1        31.03.2019  SU      1116  31.03.2019      1     SVO      AER
# 2        30.03.2019  SU      1116  31.03.2019      1     SVO      AER
# 3        29.03.2019  SU      1116  31.03.2019      1     SVO      AER
# 4        28.03.2019  SU      1116  31.03.2019      1     SVO      AER
# ...             ...  ...      ...         ...    ...      ...      ...
# 2341241  25.03.2019  SU      6186  26.10.2019      1     AER      SVO
# 2341242  24.03.2019  SU      6186  26.10.2019      1     AER      SVO
# 2341243  23.03.2019  SU      6186  26.10.2019      1     AER      SVO
# 2341244  22.03.2019  SU      6186  26.10.2019      1     AER      SVO
# 2341245  21.03.2019  SU      6186  26.10.2019      1     AER      SVO
#
#          TT_DEP  TT_ARR    SSC      CAP      UAL     SAL EQUIP  DTD
# ...

# %%
cabin.EQUIP.unique()
# Out:
# array(['333', '73H', '32B', '332', '321', '32A', '320', 'SU9', '738'],
#       dtype=object)

# %%
clas = pd.read_csv('CLASS_012018.csv', sep = ';')

# %%
clas.head(50)
# Out:
#         SDAT_S  SAK  FLT_NUM          DD  SEG_NUM SORG SDST SSCL1  \
# 0   02.01.2018  SU      1125  01.01.2018        1  AER  SVO     C
# 1   02.01.2018  SU      1125  01.01.2018        1  AER  SVO     C
# 2   02.01.2018  SU      1125  01.01.2018        1  AER  SVO     C
# 3   02.01.2018  SU      1125  01.01.2018        1  AER  SVO     C
# 4   02.01.2018  SU      1125  01.01.2018        1  AER  SVO     C
# 5   02.01.2018  SU      1125  01.01.2018        1  AER  SVO     C
# 6   02.01.2018  SU      1125  01.01.2018        1  AER  SVO     Y
# 7   02.01.2018  SU      1125  01.01.2018        1  AER  SVO     Y
# 8   02.01.2018  SU      1125  01.01.2018        1  AER  SVO     Y
# 9   02.01.2018  SU      1125  01.01.2018        1  AER  SVO     Y
# 10  02.01.2018  SU      1125  01.01.2018        1  AER  SVO     Y
# 11  02.01.2018  SU      1125  01.01.2018        1  AER  SVO     Y
# 12  02.01.2018  SU      1125  01.01.2018        1  AER  SVO     Y
# ...

# %%
dynamic = pd.DataFrame()

# %%
dynamic['date'] = pd.DataFrame(clas.DD.unique())

# %%
dynamic.date = pd.to_datetime(dynamic.date, dayfirst=True, yearfirst=False)

# %%
dynamic.sort_values(by='date', inplace=True)

# %%
dynamic['reserved'] = clas.loc['DD' == dynamic.date].SA.max() - clas.loc['DD' == dynamic.date].SA.min()
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dynamic['reserved'] = clas.loc['DD' == dynamic.date].SA.max() - clas.loc['DD' == dynamic.date].SA.min()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1292, in _LocIndexer._getitem_axis(self, key, axis)
#    1290     return self._get_slice_axis(key, axis=axis)
#    1291 elif com.is_bool_indexer(key):
# -> 1292     return self._getbool_axis(key, axis=axis)
#    1293 elif is_list_like_indexer(key):
#    1294
#    1295     # an iterable multi-selection
# ...

# %%
dynamic['reserved'] = clas.groupby(['DD']).SA.agg(max) - clas.groupby(['DD']).SA.agg(min)

# %%
df = clas.groupby(['DD', 'FLT_NUM']).SA.agg(max) - clas.groupby(['DD', 'FLT_NUM']).SA.agg(min)

# %%
df.sum()

# %%
clas.SA.max

# %%
clas
